# %%
import numpy as np
P = np.array([[0.97, 0.05, 0.10],[0.00, 0.90, 0.05],[0.03, 0.05, 0.85]])
x0 = np.array([295, 55, 150])
x1 = P @ x0
x2 = P @ x1
print("周三的汽车约略分布情况：")
print(f"机场 (Airport): {x2[0]:.2f}")
print(f"东区 (East):    {x2[1]:.2f}")
print(f"西区 (West):    {x2[2]:.2f}")
# Out:
# 周三的汽车约略分布情况：
# 机场 (Airport): 311.54
# 东区 (East):    58.26
# 西区 (West):    130.20
